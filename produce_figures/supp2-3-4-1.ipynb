# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.dirname(os.getcwd())))

import warnings
warnings.filterwarnings("ignore")
import pickle
from utils import *
import seaborn as sn
import matplotlib.pyplot as plt
import scanpy as sc
import pandas as pd
import random

# %%
colors = ['grey', 'gold', 'darkviolet', 'turquoise', 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'darkorange', 'lightgreen', 'plum', 'tan', 'khaki', 'pink', 'skyblue', 'lawngreen','salmon']

# %% [markdown]
# ### **Figure 2c**

# %%
lisi_df = pd.DataFrame({"Raw": [0.746349], 
                        "spatiAlign": [0.840238], 
                        "Harmony": [0.818728], 
                        "Combat": [ 0.746349 ], 
                        "BBKNN": [0.769687], 
                        "MNN": [0.020406],
                        "Scanorama": [  0.775168 ], 
                        "PRECAST": [0.822399], 
                        "GraphST": [ 0.827817],  
                        "SCALEX": [0.733861]})

# %%
lisi_df
# Out:
#         raw  spatiAlign   harmony    combat     bbknn       mnn  scanorama  \
# 0  0.746349    0.840238  0.818728  0.746349  0.769687  0.020406   0.775168
#
#     precast   graphst    scalex
# 0  0.822399  0.827817  0.733861

# %%
ari_df = pd.DataFrame({"Raw": [np.NAN], 
                        "spatiAlign": [0.596749], 
                        "Harmony": [0.393284], 
                        "Combat": [0.402236], 
                        "BBKNN": [0.455125], 
                        "MNN": [0.34208],
                        "Scanorama": [0.478695], 
                        "PRECAST": [0.553989], 
                        "GraphST": [ 0.437839],  
                        "SCALEX": [0.296488]})

# %%
ari_df
# Out:
#    Raw  spatiAlign   Harmony    Combat     BBKNN      MNN  Scanorama  \
# 0  NaN    0.596749  0.393284  0.402236  0.455125  0.34208   0.478695
#
#     PRECAST   GraphST    SCALEX
# 0  0.553989  0.437839  0.296488

# %%
names = lisi_df.columns[1:]

# %%
plt.figure(figsize=(8, 4))

plt.bar(range(len(names)), lisi_df[names].loc[0], color=random.sample(colors, len(names)))
x=range(len(names))
plt.grid()
plt.gca().set_axisbelow(True)
plt.xticks(x, labels=names, rotation=30, fontsize=14, ha="center")
plt.ylim(0, 1)
plt.ylabel("F1 score of LISI", fontsize=14)
for a, b in zip(x, lisi_df[names].loc[0]):
    plt.text(a, b, np.round(b, 4), ha="center", va="bottom")
plt.savefig("DLPFC_F1_scroe.pdf", dpi=150, bbox_inches="tight")

# %% [markdown]
# ### **Figure 2b**

# %%
plt.figure(figsize=(8, 4))

plt.bar(range(len(names)), ari_df[names].loc[0], color=random.sample(colors, len(names)))
x=range(len(names))
plt.grid()
plt.gca().set_axisbelow(True)
plt.xticks(x, labels=names, rotation=30, fontsize=14, ha="center")
plt.ylim(0, 1)
plt.ylabel("ARI", fontsize=14)
for a, b in zip(x, ari_df[names].loc[0]):
    plt.text(a, b, np.round(b, 4), ha="center", va="bottom")
plt.savefig("DLPFC_ari.pdf", dpi=150, bbox_inches="tight")

# %% [markdown]
# ### **supplementary Fig.S4b**

# %%
clisi_df = pd.DataFrame({
                        "spatiAlign": [0.7930], 
                        "Harmony": [0.8961], 
                        "Combat": [ 0.8792 ], 
                        "BBKNN": [0.8773], 
                        "MNN": [0.8555],
                        "Scanorama": [  0.8879 ], 
                        "PRECAST": [0.8335], 
                        "GraphST": [ 0.8479],  
                        "SCALEX": [0.8315]})

# %%
plt.figure(figsize=(8, 4))

plt.bar(range(len(names)), clisi_df[names].loc[0], color=random.sample(colors, len(names)))
x=range(len(names))
plt.grid()
plt.gca().set_axisbelow(True)
plt.xticks(x, labels=names, rotation=30, fontsize=14, ha="center")
plt.ylim(0, 1)
plt.ylabel("1-cLISI", fontsize=14)
for a, b in zip(x, clisi_df[names].loc[0]):
    plt.text(a, b, np.round(b, 4), ha="center", va="bottom")
plt.savefig("OB_cLISI.pdf", dpi=150, bbox_inches="tight")

# %% [markdown]
# ### **supplementary Fig.S4a**

# %%
ilisi_df = pd.DataFrame({
                        "spatiAlign": [0.7941], 
                        "Harmony": [0.2744], 
                        "Combat": [ 0.3656 ], 
                        "BBKNN": [0.3472], 
                        "MNN": [0.025],
                        "Scanorama": [  0.2423 ], 
                        "PRECAST": [0.5834], 
                        "GraphST": [ 0.0674],  
                        "SCALEX": [0.4816]})

# %%
plt.figure(figsize=(8, 4))

plt.bar(range(len(names)), ilisi_df[names].loc[0], color=random.sample(colors, len(names)))
x=range(len(names))
plt.grid()
plt.gca().set_axisbelow(True)
plt.xticks(x, labels=names, rotation=30, fontsize=14, ha="center")
plt.ylim(0, 1)
plt.ylabel("iLISI", fontsize=14)
for a, b in zip(x, ilisi_df[names].loc[0]):
    plt.text(a, b, np.round(b, 4), ha="center", va="bottom")
plt.savefig("OB_iLISI.pdf", dpi=150, bbox_inches="tight")

# %% [markdown]
# ### **supplementary Fig.S4c**

# %%
ari_df = pd.DataFrame({
                        "spatiAlign": [0.7095], 
                        "Harmony": [0.677], 
                        "Combat": [ 0.7426 ], 
                        "BBKNN": [0.748], 
                        "MNN": [0.7114],
                        "Scanorama": [  0.7779 ], 
                        "PRECAST": [0.6574], 
                        "GraphST": [ 0.5156],  
                        "SCALEX": [0.6319]})

# %%
plt.figure(figsize=(8, 4))

plt.bar(range(len(names)), ari_df[names].loc[0], color=random.sample(colors, len(names)))
x=range(len(names))
plt.grid()
plt.gca().set_axisbelow(True)
plt.xticks(x, labels=names, rotation=30, fontsize=14, ha="center")
plt.ylim(0, 1)
plt.ylabel("ARI", fontsize=14)
for a, b in zip(x, ari_df[names].loc[0]):
    plt.text(a, b, np.round(b, 4), ha="center", va="bottom")
plt.savefig("OB_ari.pdf", dpi=150, bbox_inches="tight")

# %% [markdown]
# ### **supplementary Fig.S2a**

# %%
ilisi_df = pd.DataFrame({
                        "spatiAlign": [0.8057], 
                        "Harmony": [0.8187], 
                        "Combat": [ 0.693 ], 
                        "BBKNN": [0.7254], 
                        "MNN": [0.],
                        "Scanorama": [  0.7232 ], 
                        "PRECAST": [0.7961], 
                        "GraphST": [ 0.9082],  
                        "SCALEX": [0.8339]})

# %%
plt.figure(figsize=(8, 4))

plt.bar(range(len(names)), ilisi_df[names].loc[0], color=random.sample(colors, len(names)))
x=range(len(names))
plt.grid()
plt.gca().set_axisbelow(True)
plt.xticks(x, labels=names, rotation=30, fontsize=14, ha="center")
plt.ylim(0, 1)
plt.ylabel("iLISI", fontsize=14)
for a, b in zip(x, ilisi_df[names].loc[0]):
    plt.text(a, b, np.round(b, 4), ha="center", va="bottom")
plt.savefig("DLPFC_iLISI.pdf", dpi=150, bbox_inches="tight")

# %% [markdown]
# ### **supplementary Fig.S2b**

# %%
clisi_df = pd.DataFrame({
                        "spatiAlign": [0.8778], 
                        "Harmony": [0.8188], 
                        "Combat": [ 0.8086 ], 
                        "BBKNN": [0.8197], 
                        "MNN": [0.8005],
                        "Scanorama": [  0.8352 ], 
                        "PRECAST": [0.8505], 
                        "GraphST": [ 0.7605],  
                        "SCALEX": [0.6553]})

# %%
plt.figure(figsize=(8, 4))

plt.bar(range(len(names)), clisi_df[names].loc[0], color=random.sample(colors, len(names)))
x=range(len(names))
plt.grid()
plt.gca().set_axisbelow(True)
plt.xticks(x, labels=names, rotation=30, fontsize=14, ha="center")
plt.ylim(0, 1)
plt.ylabel("1-cLISI", fontsize=14)
for a, b in zip(x, clisi_df[names].loc[0]):
    plt.text(a, b, np.round(b, 4), ha="center", va="bottom")
plt.savefig("DLPFC_cLISI.pdf", dpi=150, bbox_inches="tight")
